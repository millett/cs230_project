# %%
# Adapted from https://github.com/keras-team/keras/blob/master/examples/variational_autoencoder.py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
os.environ["KERAS_BACKEND"] = "tensorflow"  # Rather than Torch, for example

import keras
from keras.layers import Input, Dense, Lambda, Layer, Add, Multiply, BatchNormalization
from keras import initializers
from keras.models import Model, Sequential
from keras.objectives import binary_crossentropy
from keras.callbacks import LearningRateScheduler
from keras.callbacks import EarlyStopping
import keras.backend as K
import random
import scipy
from scipy.stats import norm
from scipy.stats import multivariate_normal
import sklearn
from sklearn import model_selection
import tensorflow as tf
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Reading in the Data

# %%
# Read in the data, make sure it's numeric
X = pd.read_csv("../aline_imputed.csv")
#X = X.iloc[:,4:]  # We don't include the patient, hospital, or ICU stay ID's because they're meaningless in this context

# %%
outcome_vars = X.columns[65:]
outcome_vars
# Out:
# Index(['icu_los_day', 'hospital_los_day', 'hosp_exp_flag', 'icu_exp_flag',
#        'day_28_flag', 'chf_flag', 'afib_flag', 'renal_flag', 'liver_flag',
#        'copd_flag', 'cad_flag', 'stroke_flag', 'malignancy_flag',
#        'respfail_flag', 'endocarditis_flag', 'ards_flag', 'pneumonia_flag'],
#       dtype='object')

# %% [markdown]
# ### Splitting into a train/test fold

# %%
# Set the train/test size
#X_model_input = X.drop(outcome_vars, axis=1)
X_train, X_test = sklearn.model_selection.train_test_split(X, train_size=0.8)
Y_train, Y_test = X_train[outcome_vars], X_test[outcome_vars]
X_train, X_test = X_train.drop(list(outcome_vars), axis=1), X_test.drop(list(outcome_vars), axis=1)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
# Convert your inputs to numpy arrays (Keras doesn't play nice with pandas dataframes)
X_train = np.array(X_train)
X_test = np.array(X_test)

# %% [markdown]
# ### Training a decoder, generator and decoder+generator VAE on the dataset

# %%
def evaluate_vae_model(X_train, X_test, latent_dimensions, intermediate_dimensions, n_epochs = 20):
    
    #Hyperparameters of interest
    intermediate_dim = intermediate_dimensions
    latent_dim = latent_dimensions
    
    # Other hyperparameters
    original_dim = X_test.shape[1]  # Calculated automatically
    batch_size = 1000  # This might affect the learning rate, but shouldn't affect the overall model outcome
    #n_epochs Not as important when we use the early stopping method (as we do in this method)
    epsilon_std = 1.0  # This shouldn't significantly change the model performance, as the z_log_sigma will adjust to accommodate
    
    # The Encoder, from the original data to the latent dimensions
    inputs = Input(shape=(original_dim,))
    hidden = Dense(intermediate_dim, activation='relu', kernel_initializer=initializers.he_normal(seed=None))(inputs)
    bn = BatchNormalization()(hidden)
    z_mean = Dense(latent_dim, activation='linear', kernel_initializer=initializers.he_normal(seed=None))(bn)
    z_log_sigma = Dense(latent_dim, activation='linear', kernel_initializer=initializers.Zeros())(bn)
    
    # The sampler
    def sample_z(args):
        z_mean, z_log_sigma = args
        eps = K.random_normal(shape=(K.shape(inputs)[0], latent_dim),
                             mean=0., stddev=1.)
        return z_mean + K.exp(z_log_sigma / 2) * eps  # Element-wise product of SD with gaussian noise, + mean vector

    z = Lambda(sample_z, output_shape=(latent_dim,))([z_mean, z_log_sigma])
    
    # The Decoder
    decoder_h = Dense(intermediate_dim, activation='relu', kernel_initializer=initializers.he_normal(seed=None))  # We don't specify the inputs because we'll use...
    decoder_bn = BatchNormalization()
    decoder_mean = Dense(original_dim, activation='linear', kernel_initializer=initializers.he_normal(seed=None))  # ...the same layers again for the generator model below
    decoder_log_sigma = Dense(original_dim, activation='linear', kernel_initializer=initializers.Zeros())
    h_decoded = decoder_h(z)
    bn_decoded = decoder_bn(h_decoded)
    output_decoded_mean = decoder_mean(bn_decoded)  # Our output is a mean vector (point estimate) and...
    output_decoded_log_sigma = decoder_log_sigma(bn_decoded)  # ...a log_sigma, or log_variance vector...
                                                            # which quantifies our certainty about the point estimate
        
    # The end-to-end autoencoder
    vae = Model(inputs, output_decoded_mean)

    # An encoder, from inputs to the latent space
    encoder = Model(inputs, z_mean)

    # A generator, from the latent space to the reconstructed inputs
    generator_input = Input(shape=(latent_dim,))
    generator_h_decoded = decoder_h(generator_input)
    generator_bn_decoded = decoder_bn(generator_h_decoded)
    generator_output_decoded_mean = decoder_mean(generator_bn_decoded)
    generator_output_decoded_log_sigma = decoder_log_sigma(generator_bn_decoded)
    generator = Model(generator_input, [generator_output_decoded_mean, generator_output_decoded_log_sigma])
    
    def vae_loss(y_true, y_pred):
        """ Calculate loss = reconstruction loss + KL loss for each data in minibatch """
        # -E[log P(X|z)]    
        reconstruction_loss = neg_log_likelihood(y_true, y_pred)

        # D_KL(Q(z|X) || P(z|X)); calculate in closed form as both dist. are Gaussian
        kl_loss = KL_divergence_loss(y_true, y_pred)

        return reconstruction_loss + kl_loss

    def neg_log_likelihood(y_true, y_pred):
        """ Calculate a proper negative log-likelihood where NLL = -log p(y_pred | mu=y_true, sigma=output_decoded_log_sigma)"""
        negative_log_likelihood = (1./2.) * \
                        (
                            K.int_shape(inputs)[1] * K.log(2. * np.pi) + \
                            K.sum(output_decoded_log_sigma, axis=-1, keepdims=True) + \
                            K.sum(
                                K.square(y_true - y_pred) * (1. / K.exp(output_decoded_log_sigma)), 
                                axis=-1, keepdims=True
                            )
                        )
        return negative_log_likelihood
    
    # An alternative loss function... should give similar results as the above, but isn't a proper NLL per-se
    def squared_difference_loss(y_true, y_pred):
        """ Calculate a naive reconstruction loss, i.e. ||y_true - y_pred||^2 """
        return K.sum(K.square(y_true - y_pred), axis=-1)  # TODO! This isn't strictly speaking the NLL, but it's a half decent approximation for now

    def KL_divergence_loss(y_true, y_pred):
        """ Calculate the KL Divergence portion of the loss, i.e. D_KL(Q(z|X) || P(z|X)) """
        return 0.5 * K.sum(K.exp(z_log_sigma) + K.square(z_mean) - 1. - z_log_sigma, axis=-1)
    
    adam = keras.optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999)
    
    vae.compile(optimizer=adam, 
                loss=vae_loss, 
                metrics=[squared_difference_loss, 
                         KL_divergence_loss, 
                         neg_log_likelihood
                        ]
               )

    #define an early stopping callback criterion so that we don't overfit
    earlystop = keras.callbacks.EarlyStopping(monitor='val_loss',  # The quantity to be monitored
                                             min_delta=0.0001,  # Minimum change in the monitored quantity in order to qualify
                                                                # as an improvement (if an absolute change of less than min_delta occurs,
                                                                # will not count as no improvement)
                                             patience=5,  # The number of epochs with no improvement after which training will be stopped
                                             verbose=0,  # Verbosity mode
                                             mode='min')  # Training will stop when the quantity monitored has stopped decreasing
    
    
    callbacks_list = [earlystop, keras.callbacks.TerminateOnNaN()]
    
    history = vae.fit(X_train,
                      X_train,
                      shuffle=True,
                      epochs=n_epochs,
                      verbose=2,
                      batch_size=batch_size,
                      callbacks=callbacks_list,
                      validation_split=0.3)
    
    X_test_encoded = encoder.predict(X_test)  # We take our test data directly from data-space to latent variable
    X_test_decoded_mean, X_test_decoded_log_sigma = generator.predict(X_test_encoded)  # space to calculate the
    
    # marginal log likelihood of the data under our fully-trained model (i.e. we don't add noise)
    test_nll = (1./2.) * \
               (
                   X_test.shape[1] * np.log(2. * np.pi) + \
                   np.sum(X_test_decoded_log_sigma, axis=-1, keepdims=True) + \
                   np.sum(
                       np.square(X_test - X_test_decoded_mean) * (1. / np.exp(X_test_decoded_log_sigma)), 
                       axis=-1, keepdims=True
                   )
               )
    
    return np.mean(test_nll), vae, encoder, generator, history

# %%
n_z = 5 # Number of units in the latent variable representation
n_h = 40 # Number of hidden units in encoder/decoder
test_err, vae, encoder, generator, history = evaluate_vae_model(X_train, X_test, n_z, n_h)
# Out:
# Train on 29329 samples, validate on 12570 samples
# Epoch 1/20
#  - 1s - loss: 96.7234 - squared_difference_loss: 68.1333 - KL_divergence_loss: 2.9257 - neg_log_likelihood: 93.7976 - val_loss: 87.1656 - val_squared_difference_loss: 47.7022 - val_KL_divergence_loss: 3.5835 - val_neg_log_likelihood: 83.5821
# Epoch 2/20
#  - 1s - loss: 85.5383 - squared_difference_loss: 45.1441 - KL_divergence_loss: 3.2352 - neg_log_likelihood: 82.3030 - val_loss: 84.8710 - val_squared_difference_loss: 41.0594 - val_KL_divergence_loss: 4.6103 - val_neg_log_likelihood: 80.2607
# Epoch 3/20
#  - 1s - loss: 84.2491 - squared_difference_loss: 41.7573 - KL_divergence_loss: 3.6394 - neg_log_likelihood: 80.6097 - val_loss: 84.2234 - val_squared_difference_loss: 39.9150 - val_KL_divergence_loss: 4.5349 - val_neg_log_likelihood: 79.6885
# Epoch 4/20
#  - 1s - loss: 83.8599 - squared_difference_loss: 40.5894 - KL_divergence_loss: 3.8342 - neg_log_likelihood: 80.0257 - val_loss: 83.9515 - val_squared_difference_loss: 39.5245 - val_KL_divergence_loss: 4.4582 - val_neg_log_likelihood: 79.4933
# Epoch 5/20
#  - 1s - loss: 83.5915 - squared_difference_loss: 39.8627 - KL_divergence_loss: 3.9292 - neg_log_likelihood: 79.6624 - val_loss: 83.5304 - val_squared_difference_loss: 38.9802 - val_KL_divergence_loss: 4.3093 - val_neg_log_likelihood: 79.2211
# Epoch 6/20
#  - 1s - loss: 83.3824 - squared_difference_loss: 39.3726 - KL_divergence_loss: 3.9651 - neg_log_likelihood: 79.4173 - val_loss: 83.4611 - val_squared_difference_loss: 38.3936 - val_KL_divergence_loss: 4.5333 - val_neg_log_likelihood: 78.9278
# Epoch 7/20
#  - 1s - loss: 83.2544 - squared_difference_loss: 38.9061 - KL_divergence_loss: 4.0703 - neg_log_likelihood: 79.1841 - val_loss: 83.2375 - val_squared_difference_loss: 38.3050 - val_KL_divergence_loss: 4.3541 - val_neg_log_likelihood: 78.8835
# Epoch 8/20
#  - 1s - loss: 83.1487 - squared_difference_loss: 38.6946 - KL_divergence_loss: 4.0704 - neg_log_likelihood: 79.0783 - val_loss: 83.0862 - val_squared_difference_loss: 37.9743 - val_KL_divergence_loss: 4.3680 - val_neg_log_likelihood: 78.7181
# Epoch 9/20
#  - 1s - loss: 83.0055 - squared_difference_loss: 38.4056 - KL_divergence_loss: 4.0717 - neg_log_likelihood: 78.9338 - val_loss: 83.0370 - val_squared_difference_loss: 37.7416 - val_KL_divergence_loss: 4.4352 - val_neg_log_likelihood: 78.6018
# Epoch 10/20
#  - 1s - loss: 82.8794 - squared_difference_loss: 38.0368 - KL_divergence_loss: 4.1300 - neg_log_likelihood: 78.7494 - val_loss: 82.9834 - val_squared_difference_loss: 37.8807 - val_KL_divergence_loss: 4.3120 - val_neg_log_likelihood: 78.6714
# Epoch 11/20
#  - 1s - loss: 82.7589 - squared_difference_loss: 37.8388 - KL_divergence_loss: 4.1085 - neg_log_likelihood: 78.6504 - val_loss: 82.8134 - val_squared_difference_loss: 37.4445 - val_KL_divergence_loss: 4.3601 - val_neg_log_likelihood: 78.4533
# Epoch 12/20
#  - 1s - loss: 82.6495 - squared_difference_loss: 37.5561 - KL_divergence_loss: 4.1405 - neg_log_likelihood: 78.5090 - val_loss: 82.6597 - val_squared_difference_loss: 37.5211 - val_KL_divergence_loss: 4.1682 - val_neg_log_likelihood: 78.4915
# Epoch 13/20
#  - 1s - loss: 82.5459 - squared_difference_loss: 37.3873 - KL_divergence_loss: 4.1213 - neg_log_likelihood: 78.4246 - val_loss: 82.6956 - val_squared_difference_loss: 37.1495 - val_KL_divergence_loss: 4.3899 - val_neg_log_likelihood: 78.3057
# Epoch 14/20
#  - 1s - loss: 82.5149 - squared_difference_loss: 37.3499 - KL_divergence_loss: 4.1089 - neg_log_likelihood: 78.4059 - val_loss: 82.4999 - val_squared_difference_loss: 36.7895 - val_KL_divergence_loss: 4.3741 - val_neg_log_likelihood: 78.1257
# Epoch 15/20
#  - 1s - loss: 82.4564 - squared_difference_loss: 37.1028 - KL_divergence_loss: 4.1740 - neg_log_likelihood: 78.2824 - val_loss: 82.4523 - val_squared_difference_loss: 37.0437 - val_KL_divergence_loss: 4.1995 - val_neg_log_likelihood: 78.2528
# Epoch 16/20
#  - 1s - loss: 82.3486 - squared_difference_loss: 36.9375 - KL_divergence_loss: 4.1488 - neg_log_likelihood: 78.1998 - val_loss: 82.3922 - val_squared_difference_loss: 36.6604 - val_KL_divergence_loss: 4.3309 - val_neg_log_likelihood: 78.0612
# Epoch 17/20
#  - 1s - loss: 82.2829 - squared_difference_loss: 36.8659 - KL_divergence_loss: 4.1189 - neg_log_likelihood: 78.1640 - val_loss: 82.2402 - val_squared_difference_loss: 36.4675 - val_KL_divergence_loss: 4.2754 - val_neg_log_likelihood: 77.9647
# Epoch 18/20
#  - 1s - loss: 82.2370 - squared_difference_loss: 36.6992 - KL_divergence_loss: 4.1564 - neg_log_likelihood: 78.0806 - val_loss: 82.2242 - val_squared_difference_loss: 36.2866 - val_KL_divergence_loss: 4.3498 - val_neg_log_likelihood: 77.8743
# Epoch 19/20
#  - 1s - loss: 82.2427 - squared_difference_loss: 36.7073 - KL_divergence_loss: 4.1581 - neg_log_likelihood: 78.0847 - val_loss: 82.2724 - val_squared_difference_loss: 36.3001 - val_KL_divergence_loss: 4.3913 - val_neg_log_likelihood: 77.8811
# Epoch 20/20
#  - 1s - loss: 82.2109 - squared_difference_loss: 36.6497 - KL_divergence_loss: 4.1550 - neg_log_likelihood: 78.0559 - val_loss: 82.1486 - val_squared_difference_loss: 35.8677 - val_KL_divergence_loss: 4.4838 - val_neg_log_likelihood: 77.6649

# %% [markdown]
# ## Graph VAE latent outputs for a subset of patients X_test, add colors for output variable

# %%
Y_test.columns.values
# Out:
# array(['icu_los_day', 'hospital_los_day', 'hosp_exp_flag', 'icu_exp_flag',
#        'day_28_flag', 'chf_flag', 'afib_flag', 'renal_flag', 'liver_flag',
#        'copd_flag', 'cad_flag', 'stroke_flag', 'malignancy_flag',
#        'respfail_flag', 'endocarditis_flag', 'ards_flag',
#        'pneumonia_flag'], dtype=object)

# %%
import sys
flag = 'hosp_exp_flag'
n_points = 1000
sys.path.append("/home/ubuntu/cs230_project/GMVAE_Experiments")
from utils import plot_labeled_data
import sklearn.manifold
latent_test = encoder.predict(X_train[:n_points])

for flag in Y_test.columns.values:
    plot_labeled_data(latent_test, np.array(Y_test[flag][:n_points]), 'figures/tsne_vanillaVAE_'+flag+'.png', True, perplexity=40)
# Out:
# i is 999
# scatter plot drawn
# i is 999
# scatter plot drawn
# i is 999
# scatter plot drawn
# i is 999
# scatter plot drawn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6701c5540ce0> in <module>()
#       8
#       9 for flag in Y_test.columns.values:
# ---> 10     plot_labeled_data(latent_test, np.array(Y_test[flag][:n_points]), 'figures/tsne_vanillaVAE_'+flag+'.png', True, perplexity=40)
#
# ~/cs230_project/GMVAE_Experiments/utils.py in plot_labeled_data(X, Y, file_name, tsne, perplexity)
#     167     cnt = 0
#     168     if tsne:
# --> 169         true_X = sklearn.manifold.TSNE(n_components=2, perplexity=perplexity).fit_transform(X)
#     170     else:
#     171         true_X = X
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     856             Embedding of the training data in low-dimensional space.
#     857         """
# --> 858         embedding = self._fit(X)
#     859         self.embedding_ = embedding
#     860         return self.embedding_
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     768                           X_embedded=X_embedded,
#     769                           neighbors=neighbors_nn,
# --> 770                           skip_num_points=skip_num_points)
#     771
#     772     @property
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#     810         P *= self.early_exaggeration
#     811         params, kl_divergence, it = _gradient_descent(obj_func, params,
# --> 812                                                       **opt_args)
#     813         if self.verbose:
#     814             print("[t-SNE] KL divergence after %d iterations with early "
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _gradient_descent(objective, p0, it, n_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     337     tic = time()
#     338     for i in range(it, n_iter):
# --> 339         error, grad = objective(p, *args, **kwargs)
#     340         grad_norm = linalg.norm(grad)
#     341
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/manifold/t_sne.py in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose)
#     245     error = _barnes_hut_tsne.gradient(val_P, X_embedded, neighbors, indptr,
#     246                                       grad, angle, n_components, verbose,
# --> 247                                       dof=degrees_of_freedom)
#     248     c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     249     grad = grad.ravel()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot Train Loss & Validation Loss vs. Number of Epochs to see our model's performance

# %%
fig, ax = plt.subplots(figsize=(8,5))

ax.plot(history.history['squared_difference_loss'], label='Train Loss')
ax.plot(history.history['val_squared_difference_loss'], label='Validation Loss')

ax.legend()


ax.set_ylabel('NELBO')
ax.set_xlabel('# epochs')

plt.title('VAE Loss vs. # of Epochs')
plt.show()

# %% [markdown]
# ### Examining the relationship between the latent variables and the original variables

# %%
input_vars = [c for c in X.columns if c not in outcome_vars]
n_examples = 20000
old_pats = X.iloc[:n_examples, :]
zvals = encoder.predict(np.array(old_pats.drop(outcome_vars, axis=1)))
# get some known patients.
min_z = -3
max_z = 3
skip = 1

latent_vars = {}
latent_input_var_spectra = {}
latent_outcome_var_spectra = {}
print("n_z = ",n_z)
for i in range(n_z):  # For each latent variable...
    latent_name = "z" + str(i)
    latent_vars[latent_name] = {}
    latent_input_var_spectra[latent_name] = np.zeros(len(input_vars))
    latent_outcome_var_spectra[latent_name] = np.zeros(len(outcome_vars))
    layer = latent_vars[latent_name]
    print("latent name",latent_name)
    for z in range(min_z, max_z, skip):  # ...fix the value of the latent variable (for a suite of values)
        zvals[:, i] = z
        new_pats = generator.predict(zvals)  # new_pats[0] is mu_x, new_pats[1] is sigma^2_x
        new_z = np.ones(n_examples) * z
        if "x" in layer:
            layer["x"] = np.concatenate((layer["x"], new_pats[0]))
        else:
            layer["x"] = new_pats[0]
        if "z" in layer:
            layer["z"] = np.concatenate((layer["z"], new_z), axis=0)
        else:
            layer["z"] = new_z
    # Take the correlation between the latent variable and all other original data variables,
    # we'll call this the latent variable's "fingerprint" or "spectrum" and we want to compare the different latent vars
    for j, real_varname in enumerate(input_vars):
        latent_input_var_spectra[latent_name][j] = np.corrcoef(latent_vars[latent_name]['z'], latent_vars[latent_name]['x'][:, j])[0, 1]
    for j, real_outcome_varname in enumerate(outcome_vars):
        correlations = np.corrcoef(latent_vars[latent_name]['z'], latent_vars[latent_name]['x'][:, j])[0, 1]
        latent_outcome_var_spectra[latent_name][j] = correlations

# %% [markdown]
# ### Calculate the top n absolute value correlations for each latent variable

# %%
n = 4
for i in range(n_z):
    latent_name = "z" + str(i)
    print('\nTop {} associated variables for Latent Variable {}:'.format(n, latent_name))
    top_n_associated_indxs = np.argsort(latent_input_var_spectra[latent_name])[::-1][:n]
    for association in zip(np.array(input_vars)[top_n_associated_indxs], 
                           latent_input_var_spectra[latent_name][top_n_associated_indxs]):
        print(association)
print('-----')   
for i in range(n_z):
    latent_name = "z" + str(i)
    print('\nTop {} associated variables for Latent Variable {}:'.format(n, latent_name))
    top_n_associated_indxs = np.argsort(latent_input_var_spectra[latent_name])[::-1][:n]
    for association in zip(np.array(outcome_vars)[top_n_associated_indxs], 
                           latent_input_var_spectra[latent_name][top_n_associated_indxs]):
        print(association)

# %% [markdown]
# ## Show correlations for each variable

# %%
for i in range(n_z):  # For each latent variable...
    plt.plot(latent_input_var_spectra["z" + str(i)], label="z" + str(i))
plt.xlabel('Original Variable Index')
plt.ylabel('Correlation with Latent Variable')
plt.title('Latent Variable Correlations for Vanilla VAE')
plt.legend(loc='upper right')
plt.show()

# %%
#pd.DataFrame(latent_input_var_spectra, index=X.columns).sort_values(by=['z0'])

# %%
# plot each latent variable against each real value
x_z_data = []  # {x: xvals, z: zvals, varname}
fignum = 0
for z_i in range(n_z):
    latent_varname = "z" + str(z_i)
    print(latent_varname)
    for j, real_varname in enumerate(input_vars):
        fignum += 1
        title = latent_varname + "_vs_" + real_varname
        x_data = latent_vars[latent_varname]["x"][:,j]
        z_data = latent_vars[latent_varname]["z"]

        plt.scatter(z_data, x_data)  # we control the hidden var, z.
        plt.title(title)
        plt.xlabel(latent_varname)
        plt.ylabel(real_varname)
        plt.savefig("figures/title"+".png")

# %%
X[X.columns.values[:-15]].head()
# Out:
#         age  weight_first  height_first       bmi  sofa_first  heartrate_min  \
# 0 -0.174367     -0.873550      0.083629 -0.986812    0.593058       1.114613
# 1 -0.912443     -0.127044      0.159537 -0.237994    0.593058       0.057324
# 2 -0.578724      0.094646     -0.371818 -0.225810   -1.029837      -0.603482
# 3 -1.198488      2.067231      0.652937  1.511980   -1.029837       0.585969
# 4 -0.955160      0.311811     -0.675449  0.740424   -0.380679       1.114613
#
#    heartrate_max  heartrate_mean  sysbp_min  sysbp_max        ...         \
# 0       1.453867        0.973430  -0.168020  -1.294207        ...
# 1       0.879022        0.885848  -0.928996  -0.343922        ...
# 2      -0.941321       -0.724069  -0.168020  -1.294207        ...
# 3       0.016754        0.546532  -0.222375  -0.219972        ...
# 4       0.112562        0.655540  -0.331086  -0.798406        ...
#
#      pt_min    pt_max  sodium_min  sodium_max   bun_min   bun_max   wbc_min  \
# 0  2.215430  0.980729    0.485343   -0.238332  2.951934  2.392836 -0.979649
# 1 -0.134198  0.639881    0.686075    0.844105 -0.252647 -0.324815  0.549150
# 2 -0.292156 -0.372008   -0.317582   -0.671307 -0.553076 -0.631647 -0.814029
# 3 -0.331646 -0.340054   -0.317582   -0.021845 -0.803434 -0.675480 -0.329910
# 4 -0.390880 -0.073767   -0.317582    0.627617 -0.452933 -0.543981  0.001330
#
#     wbc_max  icu_los_day  hospital_los_day
# 0 -0.976192            5                20
# 1  2.729527           10              1000
# 2  0.090332            5                 5
# 3 -0.226010            5                 5
# 4  0.054179            5                10
#
# [5 rows x 67 columns]

# %%
from sklearn.model_selection import KFold
X_mat = np.array(X[X.columns.values[:-15]])

n_folds = 5

num_latent_vars = [3, 4, 5, 6, 7]
num_hidden_vars = [10, 20, 30, 40, 50, 60]
# num_latent_vars = [5, 10, 15, 20, 25, 30, 50, 75, 100, 150, 250, 500, 1000]
# num_hidden_vars = [10, 25, 50, 100, 250, 500, 750, 1000, 1500, 2500, 5000]
cv_results = pd.DataFrame(0,
                           index=num_latent_vars,
                           columns=num_hidden_vars)

kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
kf.get_n_splits(X_mat)

i = 1
for lat_var_num in num_latent_vars:
    for hid_var_num in num_hidden_vars:
        print("Latent Var Num = {}".format(lat_var_num))
        print("Hidden Var Num = {}".format(hid_var_num))
        fold_num = 1
        total_nll = 0.
        
        print('Simulation #{}: VAE with {} Latent Variable(s) and {} Hidden Variable(s)...'.format(i, lat_var_num, hid_var_num))
        
        for train_index, test_index in kf.split(X_mat):
            X_train, X_test = X_mat[train_index], X_mat[test_index]
            print("\tEvaluating model on Fold {}".format(fold_num))
            total_nll += evaluate_vae_model(X_train, 
                                            X_test, 
                                            latent_dimensions=lat_var_num, 
                                            intermediate_dimensions=hid_var_num, n_epochs=50)[0]
            if total_nll == float('NaN'):
                break
            fold_num += 1
            if fold_num > 1:
                break

        cv_results.loc[lat_var_num, hid_var_num] = total_nll #/ n_folds
        print('\tAverage Validation Squared Error = {}'.format(total_nll))# / n_folds))
        i += 1
# Out:
# Latent Var Num = 3
# Hidden Var Num = 10
# Simulation #1: VAE with 3 Latent Variable(s) and 10 Hidden Variable(s)...
# 	Evaluating model on Fold 1
# Train on 29329 samples, validate on 12570 samples
# Epoch 1/50
#  - 12s - loss: 82851.8870 - squared_difference_loss: 165572.2821 - KL_divergence_loss: 4.1720 - neg_log_likelihood: 82847.7126 - val_loss: 80201.2922 - val_squared_difference_loss: 160261.1815 - val_KL_divergence_loss: 9.1417 - val_neg_log_likelihood: 80192.1540
# Epoch 2/50
#  - 1s - loss: 79924.0130 - squared_difference_loss: 159700.8461 - KL_divergence_loss: 12.0175 - neg_log_likelihood: 79911.9944 - val_loss: 76309.2351 - val_squared_difference_loss: 152452.3825 - val_KL_divergence_loss: 21.4740 - val_neg_log_likelihood: 76287.7641
# Epoch 3/50
#  - 1s - loss: 74729.6751 - squared_difference_loss: 149287.4492 - KL_divergence_loss: 24.3841 - neg_log_likelihood: 74705.2934 - val_loss: 70729.2097 - val_squared_difference_loss: 141273.6453 - val_KL_divergence_loss: 30.8163 - val_neg_log_likelihood: 70698.3864
# Epoch 4/50
#  - 1s - loss: 67662.8277 - squared_difference_loss: 135149.5435 - KL_divergence_loss: 26.4906 - neg_log_likelihood: 67636.3376 - val_loss: 64080.8246 - val_squared_difference_loss: 127982.8263 - val_KL_divergence_loss: 27.8455 - val_neg_log_likelihood: 64052.9885
# Epoch 5/50
#  - 1s - loss: 59401.6132 - squared_difference_loss: 118634.7594 - KL_divergence_loss: 22.6679 - neg_log_likelihood: 59378.9479 - val_loss: 58113.1578 - val_squared_difference_loss: 116058.0524 - val_KL_divergence_loss: 22.5634 - val_neg_log_likelihood: 58090.5951
# Epoch 6/50
#  - 1s - loss: 50857.2724 - squared_difference_loss: 101553.2800 - KL_divergence_loss: 19.0615 - neg_log_likelihood: 50838.2106 - val_loss: 52576.7115 - val_squared_difference_loss: 104992.9420 - val_KL_divergence_loss: 18.6735 - val_neg_log_likelihood: 52558.0392
# Epoch 7/50
#  - 1s - loss: 42741.9265 - squared_difference_loss: 85327.9873 - KL_divergence_loss: 16.3663 - neg_log_likelihood: 42725.5607 - val_loss: 44754.9802 - val_squared_difference_loss: 89353.6516 - val_KL_divergence_loss: 16.5920 - val_neg_log_likelihood: 44738.3914
# Epoch 8/50
#  - 1s - loss: 35414.6166 - squared_difference_loss: 70676.6373 - KL_divergence_loss: 14.7288 - neg_log_likelihood: 35399.8858 - val_loss: 38956.7484 - val_squared_difference_loss: 77759.3585 - val_KL_divergence_loss: 15.5032 - val_neg_log_likelihood: 38941.2486
# Epoch 9/50
#  - 1s - loss: 29061.0743 - squared_difference_loss: 57970.8876 - KL_divergence_loss: 14.0637 - neg_log_likelihood: 29047.0112 - val_loss: 33054.0761 - val_squared_difference_loss: 65955.0618 - val_KL_divergence_loss: 14.9741 - val_neg_log_likelihood: 33039.0975
# Epoch 10/50
#  - 1s - loss: 23663.1122 - squared_difference_loss: 47175.2832 - KL_divergence_loss: 13.9018 - neg_log_likelihood: 23649.2093 - val_loss: 25556.8758 - val_squared_difference_loss: 50961.3314 - val_KL_divergence_loss: 14.6440 - val_neg_log_likelihood: 25542.2344
# Epoch 11/50
#  - 1s - loss: 19202.9207 - squared_difference_loss: 38255.0031 - KL_divergence_loss: 13.8491 - neg_log_likelihood: 19189.0717 - val_loss: 19770.3665 - val_squared_difference_loss: 39388.3220 - val_KL_divergence_loss: 14.6361 - val_neg_log_likelihood: 19755.7291
# Epoch 12/50
#  - 1s - loss: 15628.9964 - squared_difference_loss: 31106.7470 - KL_divergence_loss: 14.0541 - neg_log_likelihood: 15614.9423 - val_loss: 14751.4738 - val_squared_difference_loss: 29350.1631 - val_KL_divergence_loss: 14.8228 - val_neg_log_likelihood: 14736.6503
# Epoch 13/50
#  - 1s - loss: 12804.2337 - squared_difference_loss: 25456.4902 - KL_divergence_loss: 14.4205 - neg_log_likelihood: 12789.8128 - val_loss: 11871.7282 - val_squared_difference_loss: 23590.7729 - val_KL_divergence_loss: 14.7722 - val_neg_log_likelihood: 11856.9562
# Epoch 14/50
#  - 1s - loss: 10452.0418 - squared_difference_loss: 20751.8868 - KL_divergence_loss: 14.5296 - neg_log_likelihood: 10437.5122 - val_loss: 9117.3073 - val_squared_difference_loss: 18081.9659 - val_KL_divergence_loss: 14.7547 - val_neg_log_likelihood: 9102.5524
# Epoch 15/50
#  - 1s - loss: 7748.5170 - squared_difference_loss: 15342.7534 - KL_divergence_loss: 15.5712 - neg_log_likelihood: 7732.9461 - val_loss: 11882.7196 - val_squared_difference_loss: 23606.5734 - val_KL_divergence_loss: 17.8637 - val_neg_log_likelihood: 11864.8573
# Epoch 16/50
#  - 1s - loss: 5203.7816 - squared_difference_loss: 10247.2276 - KL_divergence_loss: 18.5990 - neg_log_likelihood: 5185.1829 - val_loss: 10892.7596 - val_squared_difference_loss: 21621.8197 - val_KL_divergence_loss: 20.2815 - val_neg_log_likelihood: 10872.4787
# Epoch 17/50
#  - 1s - loss: 3398.0189 - squared_difference_loss: 6635.3094 - KL_divergence_loss: 18.7955 - neg_log_likelihood: 3379.2235 - val_loss: 3365.1192 - val_squared_difference_loss: 6568.0447 - val_KL_divergence_loss: 19.5282 - val_neg_log_likelihood: 3345.5911
# Epoch 18/50
#  - 1s - loss: 2132.2167 - squared_difference_loss: 4103.9673 - KL_divergence_loss: 18.6642 - neg_log_likelihood: 2113.5526 - val_loss: 1910.4131 - val_squared_difference_loss: 3658.9232 - val_KL_divergence_loss: 19.3827 - val_neg_log_likelihood: 1891.0304
# Epoch 19/50
#  - 1s - loss: 1393.1356 - squared_difference_loss: 2625.5343 - KL_divergence_loss: 18.7995 - neg_log_likelihood: 1374.3360 - val_loss: 1204.2096 - val_squared_difference_loss: 2246.6538 - val_KL_divergence_loss: 19.3139 - val_neg_log_likelihood: 1184.8957
# Epoch 20/50
#  - 1s - loss: 944.3871 - squared_difference_loss: 1728.0555 - KL_divergence_loss: 18.7905 - neg_log_likelihood: 925.5966 - val_loss: 572.9458 - val_squared_difference_loss: 984.7997 - val_KL_divergence_loss: 18.9770 - val_neg_log_likelihood: 553.9688
# Epoch 21/50
#  - 1s - loss: 627.4852 - squared_difference_loss: 1094.6297 - KL_divergence_loss: 18.6014 - neg_log_likelihood: 608.8837 - val_loss: 673.5902 - val_squared_difference_loss: 1186.1893 - val_KL_divergence_loss: 18.9267 - val_neg_log_likelihood: 654.6636
# Epoch 22/50
#  - 1s - loss: 565.8857 - squared_difference_loss: 970.9504 - KL_divergence_loss: 18.8416 - neg_log_likelihood: 547.0441 - val_loss: 869.7756 - val_squared_difference_loss: 1578.2392 - val_KL_divergence_loss: 19.0871 - val_neg_log_likelihood: 850.6885
# Epoch 23/50
#  - 1s - loss: 465.4602 - squared_difference_loss: 770.0866 - KL_divergence_loss: 18.8480 - neg_log_likelihood: 446.6122 - val_loss: 644.9121 - val_squared_difference_loss: 1128.6537 - val_KL_divergence_loss: 19.0163 - val_neg_log_likelihood: 625.8957
# Epoch 24/50
#  - 1s - loss: 532.8026 - squared_difference_loss: 905.1328 - KL_divergence_loss: 18.6674 - neg_log_likelihood: 514.1353 - val_loss: 468.1710 - val_squared_difference_loss: 775.6882 - val_KL_divergence_loss: 18.7581 - val_neg_log_likelihood: 449.4129
# Epoch 25/50
#  - 1s - loss: 352.4661 - squared_difference_loss: 544.9621 - KL_divergence_loss: 18.4162 - neg_log_likelihood: 334.0500 - val_loss: 530.3117 - val_squared_difference_loss: 900.4878 - val_KL_divergence_loss: 18.4990 - val_neg_log_likelihood: 511.8127
# Epoch 26/50
#  - 1s - loss: 364.3917 - squared_difference_loss: 569.1259 - KL_divergence_loss: 18.2598 - neg_log_likelihood: 346.1319 - val_loss: 226.3338 - val_squared_difference_loss: 292.9807 - val_KL_divergence_loss: 18.2746 - val_neg_log_likelihood: 208.0592
# Epoch 27/50
#  - 1s - loss: 437.8136 - squared_difference_loss: 716.1390 - KL_divergence_loss: 18.1752 - neg_log_likelihood: 419.6384 - val_loss: 917.8383 - val_squared_difference_loss: 1675.2358 - val_KL_divergence_loss: 18.6515 - val_neg_log_likelihood: 899.1868
# Epoch 28/50
#  - 1s - loss: 416.6409 - squared_difference_loss: 673.3535 - KL_divergence_loss: 18.3953 - neg_log_likelihood: 398.2456 - val_loss: 542.6616 - val_squared_difference_loss: 925.6375 - val_KL_divergence_loss: 18.2739 - val_neg_log_likelihood: 524.3877
# Epoch 29/50
#  - 1s - loss: 402.3120 - squared_difference_loss: 645.3606 - KL_divergence_loss: 18.0628 - neg_log_likelihood: 384.2491 - val_loss: 372.8930 - val_squared_difference_loss: 586.6839 - val_KL_divergence_loss: 17.9822 - val_neg_log_likelihood: 354.9108
# Epoch 30/50
#  - 1s - loss: 307.8273 - squared_difference_loss: 456.6079 - KL_divergence_loss: 17.9544 - neg_log_likelihood: 289.8728 - val_loss: 356.6112 - val_squared_difference_loss: 554.2419 - val_KL_divergence_loss: 17.9214 - val_neg_log_likelihood: 338.6898
# Epoch 31/50
#  - 1s - loss: 419.3763 - squared_difference_loss: 680.0278 - KL_divergence_loss: 17.7936 - neg_log_likelihood: 401.5828 - val_loss: 890.0267 - val_squared_difference_loss: 1622.0135 - val_KL_divergence_loss: 17.4510 - val_neg_log_likelihood: 872.5756
# Epoch 32/50
#  - 1s - loss: 392.7297 - squared_difference_loss: 624.0415 - KL_divergence_loss: 19.1401 - neg_log_likelihood: 373.5896 - val_loss: 19808.0259 - val_squared_difference_loss: 39452.7679 - val_KL_divergence_loss: 20.0730 - val_neg_log_likelihood: 19787.9526
# Epoch 33/50
#  - 1s - loss: 355.5141 - squared_difference_loss: 548.3683 - KL_divergence_loss: 19.7611 - neg_log_likelihood: 335.7530 - val_loss: 9591.6472 - val_squared_difference_loss: 19021.4114 - val_KL_divergence_loss: 19.3718 - val_neg_log_likelihood: 9572.2753
# Epoch 34/50
#  - 1s - loss: 321.2803 - squared_difference_loss: 481.2956 - KL_divergence_loss: 19.0636 - neg_log_likelihood: 302.2167 - val_loss: 3476.1119 - val_squared_difference_loss: 6791.8843 - val_KL_divergence_loss: 18.6010 - val_neg_log_likelihood: 3457.5110
# Epoch 35/50
#  - 1s - loss: 438.9683 - squared_difference_loss: 718.3297 - KL_divergence_loss: 18.2345 - neg_log_likelihood: 420.7338 - val_loss: 1803.3040 - val_squared_difference_loss: 3447.9684 - val_KL_divergence_loss: 17.7510 - val_neg_log_likelihood: 1785.5531
# Epoch 36/50
#  - 1s - loss: 464.1736 - squared_difference_loss: 769.6595 - KL_divergence_loss: 17.7750 - neg_log_likelihood: 446.3986 - val_loss: 832.1385 - val_squared_difference_loss: 1505.7121 - val_KL_divergence_loss: 17.7135 - val_neg_log_likelihood: 814.4250
# Epoch 37/50
#  - 1s - loss: 402.4125 - squared_difference_loss: 646.4775 - KL_divergence_loss: 17.6048 - neg_log_likelihood: 384.8076 - val_loss: 399.4386 - val_squared_difference_loss: 640.7773 - val_KL_divergence_loss: 17.4810 - val_neg_log_likelihood: 381.9575
# Epoch 38/50
#  - 1s - loss: 331.2504 - squared_difference_loss: 504.6608 - KL_divergence_loss: 17.3511 - neg_log_likelihood: 313.8993 - val_loss: 797.5423 - val_squared_difference_loss: 1437.2109 - val_KL_divergence_loss: 17.3679 - val_neg_log_likelihood: 780.1743
# Epoch 39/50
#  - 1s - loss: 390.7042 - squared_difference_loss: 623.7666 - KL_divergence_loss: 17.2520 - neg_log_likelihood: 373.4522 - val_loss: 855.9193 - val_squared_difference_loss: 1553.6097 - val_KL_divergence_loss: 17.5456 - val_neg_log_likelihood: 838.3737
# Epoch 40/50
#  - 1s - loss: 357.3159 - squared_difference_loss: 556.3543 - KL_divergence_loss: 17.5698 - neg_log_likelihood: 339.7461 - val_loss: 1565.2121 - val_squared_difference_loss: 2972.6026 - val_KL_divergence_loss: 17.3420 - val_neg_log_likelihood: 1547.8701
# Epoch 41/50
#  - 1s - loss: 394.4899 - squared_difference_loss: 631.2642 - KL_divergence_loss: 17.2890 - neg_log_likelihood: 377.2010 - val_loss: 962.8111 - val_squared_difference_loss: 1768.1078 - val_KL_divergence_loss: 17.1882 - val_neg_log_likelihood: 945.6228
# Epoch 42/50
#  - 1s - loss: 400.3430 - squared_difference_loss: 643.1975 - KL_divergence_loss: 17.1754 - neg_log_likelihood: 383.1676 - val_loss: 1085.2447 - val_squared_difference_loss: 2013.2266 - val_KL_divergence_loss: 17.0625 - val_neg_log_likelihood: 1068.1822
# Epoch 43/50
#  - 1s - loss: 371.9799 - squared_difference_loss: 586.5758 - KL_divergence_loss: 17.1231 - neg_log_likelihood: 354.8568 - val_loss: 802.5452 - val_squared_difference_loss: 1447.1365 - val_KL_divergence_loss: 17.4080 - val_neg_log_likelihood: 785.1371
# Epoch 44/50
#  - 1s - loss: 320.8321 - squared_difference_loss: 484.1578 - KL_divergence_loss: 17.1843 - neg_log_likelihood: 303.6478 - val_loss: 462.2664 - val_squared_difference_loss: 767.5335 - val_KL_divergence_loss: 16.9308 - val_neg_log_likelihood: 445.3356
# Epoch 45/50
#  - 1s - loss: 342.9628 - squared_difference_loss: 528.8140 - KL_divergence_loss: 16.9869 - neg_log_likelihood: 325.9759 - val_loss: 323.9889 - val_squared_difference_loss: 491.3302 - val_KL_divergence_loss: 16.7549 - val_neg_log_likelihood: 307.2340
# Epoch 46/50
#  - 1s - loss: 359.0495 - squared_difference_loss: 561.2039 - KL_divergence_loss: 16.8786 - neg_log_likelihood: 342.1708 - val_loss: 804.1518 - val_squared_difference_loss: 1452.1780 - val_KL_divergence_loss: 16.4938 - val_neg_log_likelihood: 787.6579
# Epoch 47/50
#  - 1s - loss: 380.2834 - squared_difference_loss: 603.5567 - KL_divergence_loss: 16.9362 - neg_log_likelihood: 363.3472 - val_loss: 391.5990 - val_squared_difference_loss: 626.6610 - val_KL_divergence_loss: 16.6996 - val_neg_log_likelihood: 374.8994
# Epoch 48/50
#  - 1s - loss: 337.3741 - squared_difference_loss: 517.9130 - KL_divergence_loss: 16.8487 - neg_log_likelihood: 320.5254 - val_loss: 230.1211 - val_squared_difference_loss: 303.5430 - val_KL_divergence_loss: 16.7807 - val_neg_log_likelihood: 213.3404
# Epoch 49/50
#  - 1s - loss: 310.5424 - squared_difference_loss: 464.3728 - KL_divergence_loss: 16.7871 - neg_log_likelihood: 293.7553 - val_loss: 182.2637 - val_squared_difference_loss: 208.1332 - val_KL_divergence_loss: 16.6282 - val_neg_log_likelihood: 165.6355
# Epoch 50/50
#  - 1s - loss: 382.4609 - squared_difference_loss: 608.3879 - KL_divergence_loss: 16.6980 - neg_log_likelihood: 365.7629 - val_loss: 225.8475 - val_squared_difference_loss: 295.7283 - val_KL_divergence_loss: 16.4145 - val_neg_log_likelihood: 209.4330
# 	Average Validation Squared Error = 41.58478406584584
# Latent Var Num = 3
# Hidden Var Num = 20
# Simulation #2: VAE with 3 Latent Variable(s) and 20 Hidden Variable(s)...
# 	Evaluating model on Fold 1
# Train on 29329 samples, validate on 12570 samples
# Epoch 1/50
#  - 11s - loss: 82181.2294 - squared_difference_loss: 164229.0810 - KL_divergence_loss: 5.1223 - neg_log_likelihood: 82176.1131 - val_loss: 78500.0642 - val_squared_difference_loss: 156847.3068 - val_KL_divergence_loss: 14.8454 - val_neg_log_likelihood: 78485.2194
# Epoch 2/50
#  - 1s - loss: 76426.9450 - squared_difference_loss: 152681.7672 - KL_divergence_loss: 24.4947 - neg_log_likelihood: 76402.4508 - val_loss: 71126.1481 - val_squared_difference_loss: 142053.5302 - val_KL_divergence_loss: 37.8187 - val_neg_log_likelihood: 71088.3378
# Epoch 3/50
#  - 1s - loss: 67274.1698 - squared_difference_loss: 134359.2278 - KL_divergence_loss: 32.9873 - neg_log_likelihood: 67241.1806 - val_loss: 62510.0299 - val_squared_difference_loss: 124833.3997 - val_KL_divergence_loss: 31.7622 - val_neg_log_likelihood: 62478.2669
# Epoch 4/50
#  - 1s - loss: 55861.7849 - squared_difference_loss: 111549.5124 - KL_divergence_loss: 25.4596 - neg_log_likelihood: 55836.3238 - val_loss: 55413.0523 - val_squared_difference_loss: 110654.2710 - val_KL_divergence_loss: 24.3473 - val_neg_log_likelihood: 55388.7024
# Epoch 5/50
#  - 1s - loss: 43614.0656 - squared_difference_loss: 87062.3971 - KL_divergence_loss: 21.2984 - neg_log_likelihood: 43592.7661 - val_loss: 48519.3283 - val_squared_difference_loss: 96871.7721 - val_KL_divergence_loss: 21.8774 - val_neg_log_likelihood: 48497.4502
# Epoch 6/50
#  - 1s - loss: 32613.9417 - squared_difference_loss: 65064.7560 - KL_divergence_loss: 19.9955 - neg_log_likelihood: 32593.9460 - val_loss: 43291.3828 - val_squared_difference_loss: 86417.9564 - val_KL_divergence_loss: 20.8350 - val_neg_log_likelihood: 43270.5463
# Epoch 7/50
#  - 1s - loss: 23347.5407 - squared_difference_loss: 46530.4822 - KL_divergence_loss: 20.7306 - neg_log_likelihood: 23326.8096 - val_loss: 31153.8583 - val_squared_difference_loss: 62140.4131 - val_KL_divergence_loss: 22.0803 - val_neg_log_likelihood: 31131.7776
# Epoch 8/50
#  - 1s - loss: 16231.0693 - squared_difference_loss: 32296.0176 - KL_divergence_loss: 21.4920 - neg_log_likelihood: 16209.5778 - val_loss: 24634.9520 - val_squared_difference_loss: 49102.7308 - val_KL_divergence_loss: 22.0181 - val_neg_log_likelihood: 24612.9346
# Epoch 9/50
#  - 1s - loss: 11111.4310 - squared_difference_loss: 22057.1622 - KL_divergence_loss: 21.2806 - neg_log_likelihood: 11090.1496 - val_loss: 18640.2632 - val_squared_difference_loss: 37113.9629 - val_KL_divergence_loss: 21.7135 - val_neg_log_likelihood: 18618.5503
# Epoch 10/50
#  - 1s - loss: 7565.0761 - squared_difference_loss: 14964.1014 - KL_divergence_loss: 21.4559 - neg_log_likelihood: 7543.6198 - val_loss: 10458.8414 - val_squared_difference_loss: 20750.8708 - val_KL_divergence_loss: 21.8361 - val_neg_log_likelihood: 10437.0039
# Epoch 11/50
#  - 1s - loss: 4505.6491 - squared_difference_loss: 8844.8899 - KL_divergence_loss: 21.6355 - neg_log_likelihood: 4484.0137 - val_loss: 5611.3572 - val_squared_difference_loss: 11056.5810 - val_KL_divergence_loss: 21.4979 - val_neg_log_likelihood: 5589.8589
# Epoch 12/50
#  - 1s - loss: 2707.0439 - squared_difference_loss: 5248.0265 - KL_divergence_loss: 21.4619 - neg_log_likelihood: 2685.5821 - val_loss: 3338.9611 - val_squared_difference_loss: 6513.0971 - val_KL_divergence_loss: 20.8436 - val_neg_log_likelihood: 3318.1174
# Epoch 13/50
#  - 1s - loss: 1591.9738 - squared_difference_loss: 3020.1915 - KL_divergence_loss: 20.3092 - neg_log_likelihood: 1571.6647 - val_loss: 3227.2603 - val_squared_difference_loss: 6291.2225 - val_KL_divergence_loss: 20.0802 - val_neg_log_likelihood: 3207.1800
# Epoch 14/50
#  - 1s - loss: 858.0600 - squared_difference_loss: 1553.1671 - KL_divergence_loss: 19.9076 - neg_log_likelihood: 838.1524 - val_loss: 4296.3923 - val_squared_difference_loss: 8427.6117 - val_KL_divergence_loss: 21.0173 - val_neg_log_likelihood: 4275.3746
# Epoch 15/50
#  - 1s - loss: 628.7678 - squared_difference_loss: 1095.2156 - KL_divergence_loss: 19.5911 - neg_log_likelihood: 609.1767 - val_loss: 1965.2294 - val_squared_difference_loss: 3766.7262 - val_KL_divergence_loss: 20.2973 - val_neg_log_likelihood: 1944.9320
# Epoch 16/50
#  - 1s - loss: 391.6824 - squared_difference_loss: 621.7043 - KL_divergence_loss: 19.2613 - neg_log_likelihood: 372.4210 - val_loss: 2292.6456 - val_squared_difference_loss: 4422.5020 - val_KL_divergence_loss: 19.8256 - val_neg_log_likelihood: 2272.8199
# Epoch 17/50
#  - 1s - loss: 476.6132 - squared_difference_loss: 792.5035 - KL_divergence_loss: 18.7925 - neg_log_likelihood: 457.8206 - val_loss: 2742.8433 - val_squared_difference_loss: 5323.6972 - val_KL_divergence_loss: 19.4255 - val_neg_log_likelihood: 2723.4177
# Epoch 18/50
#  - 1s - loss: 504.1615 - squared_difference_loss: 848.3656 - KL_divergence_loss: 18.4099 - neg_log_likelihood: 485.7517 - val_loss: 923.3336 - val_squared_difference_loss: 1686.4643 - val_KL_divergence_loss: 18.5326 - val_neg_log_likelihood: 904.8010
# Epoch 19/50
#  - 1s - loss: 445.6983 - squared_difference_loss: 732.2410 - KL_divergence_loss: 18.0089 - neg_log_likelihood: 427.6894 - val_loss: 3369.1364 - val_squared_difference_loss: 6578.7191 - val_KL_divergence_loss: 18.2078 - val_neg_log_likelihood: 3350.9287
# Epoch 20/50
#  - 1s - loss: 370.4906 - squared_difference_loss: 582.1824 - KL_divergence_loss: 17.8304 - neg_log_likelihood: 352.6601 - val_loss: 1335.0196 - val_squared_difference_loss: 2510.6880 - val_KL_divergence_loss: 18.1066 - val_neg_log_likelihood: 1316.9130
# Epoch 21/50
#  - 1s - loss: 335.5750 - squared_difference_loss: 512.2638 - KL_divergence_loss: 17.8742 - neg_log_likelihood: 317.7008 - val_loss: 918.3423 - val_squared_difference_loss: 1677.9895 - val_KL_divergence_loss: 17.7786 - val_neg_log_likelihood: 900.5637
# Epoch 22/50
#  - 1s - loss: 444.7031 - squared_difference_loss: 731.1249 - KL_divergence_loss: 17.5717 - neg_log_likelihood: 427.1313 - val_loss: 1517.1573 - val_squared_difference_loss: 2876.0338 - val_KL_divergence_loss: 17.5715 - val_neg_log_likelihood: 1499.5857
# Epoch 23/50
#  - 2s - loss: 436.5334 - squared_difference_loss: 715.1446 - KL_divergence_loss: 17.3922 - neg_log_likelihood: 419.1412 - val_loss: 1241.6367 - val_squared_difference_loss: 2325.9177 - val_KL_divergence_loss: 17.1090 - val_neg_log_likelihood: 1224.5278
# Epoch 24/50
#  - 2s - loss: 351.3371 - squared_difference_loss: 545.3746 - KL_divergence_loss: 17.0809 - neg_log_likelihood: 334.2562 - val_loss: 1493.8177 - val_squared_difference_loss: 2829.9922 - val_KL_divergence_loss: 17.2528 - val_neg_log_likelihood: 1476.5650
# Epoch 25/50
#  - 1s - loss: 345.0192 - squared_difference_loss: 532.9299 - KL_divergence_loss: 16.9853 - neg_log_likelihood: 328.0338 - val_loss: 1034.7062 - val_squared_difference_loss: 1912.2921 - val_KL_divergence_loss: 16.9913 - val_neg_log_likelihood: 1017.7149
# Epoch 26/50
#  - 1s - loss: 412.9190 - squared_difference_loss: 668.6589 - KL_divergence_loss: 17.0207 - neg_log_likelihood: 395.8983 - val_loss: 653.4826 - val_squared_difference_loss: 1150.1813 - val_KL_divergence_loss: 16.8231 - val_neg_log_likelihood: 636.6596
# Epoch 27/50
#  - 1s - loss: 361.7091 - squared_difference_loss: 566.5383 - KL_divergence_loss: 16.8711 - neg_log_likelihood: 344.8380 - val_loss: 312.3470 - val_squared_difference_loss: 467.9019 - val_KL_divergence_loss: 16.8272 - val_neg_log_likelihood: 295.5199
# Epoch 28/50
#  - 1s - loss: 324.2619 - squared_difference_loss: 491.8967 - KL_divergence_loss: 16.7446 - neg_log_likelihood: 307.5173 - val_loss: 161.1387 - val_squared_difference_loss: 165.7540 - val_KL_divergence_loss: 16.6928 - val_neg_log_likelihood: 144.4459
# Epoch 29/50
#  - 1s - loss: 471.7517 - squared_difference_loss: 787.0058 - KL_divergence_loss: 16.6800 - neg_log_likelihood: 455.0718 - val_loss: 1108.5892 - val_squared_difference_loss: 2061.0583 - val_KL_divergence_loss: 16.4911 - val_neg_log_likelihood: 1092.0981
# Epoch 30/50
#  - 1s - loss: 393.8327 - squared_difference_loss: 631.8483 - KL_divergence_loss: 16.3396 - neg_log_likelihood: 377.4931 - val_loss: 289.6306 - val_squared_difference_loss: 423.7316 - val_KL_divergence_loss: 16.1959 - val_neg_log_likelihood: 273.4347
# Epoch 31/50
#  - 1s - loss: 447.1750 - squared_difference_loss: 738.6144 - KL_divergence_loss: 16.2989 - neg_log_likelihood: 430.8761 - val_loss: 304.7226 - val_squared_difference_loss: 453.6925 - val_KL_divergence_loss: 16.3075 - val_neg_log_likelihood: 288.4151
# Epoch 32/50
#  - 1s - loss: 360.8866 - squared_difference_loss: 566.1083 - KL_divergence_loss: 16.2635 - neg_log_likelihood: 344.6230 - val_loss: 969.2073 - val_squared_difference_loss: 1782.9171 - val_KL_divergence_loss: 16.1798 - val_neg_log_likelihood: 953.0275
# Epoch 33/50
#  - 1s - loss: 310.3915 - squared_difference_loss: 465.2944 - KL_divergence_loss: 16.1754 - neg_log_likelihood: 294.2161 - val_loss: 714.9228 - val_squared_difference_loss: 1274.5487 - val_KL_divergence_loss: 16.0795 - val_neg_log_likelihood: 698.8432
# Epoch 34/50
#  - 1s - loss: 373.7691 - squared_difference_loss: 591.9983 - KL_divergence_loss: 16.2011 - neg_log_likelihood: 357.5680 - val_loss: 221.5567 - val_squared_difference_loss: 287.7446 - val_KL_divergence_loss: 16.1156 - val_neg_log_likelihood: 205.4412
# Epoch 35/50
#  - 1s - loss: 461.4680 - squared_difference_loss: 767.3973 - KL_divergence_loss: 16.2005 - neg_log_likelihood: 445.2675 - val_loss: 331.0199 - val_squared_difference_loss: 506.8387 - val_KL_divergence_loss: 16.0317 - val_neg_log_likelihood: 314.9882
# Epoch 36/50
#  - 1s - loss: 332.4242 - squared_difference_loss: 509.5752 - KL_divergence_loss: 16.0677 - neg_log_likelihood: 316.3565 - val_loss: 215.1457 - val_squared_difference_loss: 275.2207 - val_KL_divergence_loss: 15.9665 - val_neg_log_likelihood: 199.1792
# Epoch 37/50
#  - 1s - loss: 345.9816 - squared_difference_loss: 536.4910 - KL_divergence_loss: 16.1672 - neg_log_likelihood: 329.8144 - val_loss: 773.2512 - val_squared_difference_loss: 1391.4744 - val_KL_divergence_loss: 15.9450 - val_neg_log_likelihood: 757.3061
# Epoch 38/50
#  - 1s - loss: 451.4573 - squared_difference_loss: 747.8317 - KL_divergence_loss: 15.9726 - neg_log_likelihood: 435.4848 - val_loss: 344.8175 - val_squared_difference_loss: 535.0396 - val_KL_divergence_loss: 15.7288 - val_neg_log_likelihood: 329.0887
# Epoch 39/50
#  - 1s - loss: 366.7252 - squared_difference_loss: 578.6562 - KL_divergence_loss: 15.8283 - neg_log_likelihood: 350.8970 - val_loss: 458.1548 - val_squared_difference_loss: 762.0958 - val_KL_divergence_loss: 15.5380 - val_neg_log_likelihood: 442.6168
# Epoch 40/50
#  - 1s - loss: 302.9622 - squared_difference_loss: 451.2777 - KL_divergence_loss: 15.7545 - neg_log_likelihood: 287.2078 - val_loss: 960.7227 - val_squared_difference_loss: 1766.7294 - val_KL_divergence_loss: 15.7892 - val_neg_log_likelihood: 944.9336
# Epoch 41/50
#  - 1s - loss: 389.5687 - squared_difference_loss: 624.1627 - KL_divergence_loss: 15.9185 - neg_log_likelihood: 373.6503 - val_loss: 601.1587 - val_squared_difference_loss: 1047.8140 - val_KL_divergence_loss: 15.6828 - val_neg_log_likelihood: 585.4759
# Epoch 42/50
#  - 1s - loss: 335.2540 - squared_difference_loss: 515.6196 - KL_divergence_loss: 15.8753 - neg_log_likelihood: 319.3787 - val_loss: 522.5453 - val_squared_difference_loss: 890.4452 - val_KL_divergence_loss: 15.7538 - val_neg_log_likelihood: 506.7915
# Epoch 43/50
#  - 1s - loss: 393.0321 - squared_difference_loss: 631.2296 - KL_divergence_loss: 15.8484 - neg_log_likelihood: 377.1836 - val_loss: 208.6502 - val_squared_difference_loss: 262.6696 - val_KL_divergence_loss: 15.7465 - val_neg_log_likelihood: 192.9037
# Epoch 44/50
#  - 1s - loss: 317.9453 - squared_difference_loss: 481.1335 - KL_divergence_loss: 15.8097 - neg_log_likelihood: 302.1356 - val_loss: 452.7028 - val_squared_difference_loss: 750.8115 - val_KL_divergence_loss: 15.7282 - val_neg_log_likelihood: 436.9746
# Epoch 45/50
#  - 1s - loss: 484.8839 - squared_difference_loss: 815.3022 - KL_divergence_loss: 15.6639 - neg_log_likelihood: 469.2200 - val_loss: 463.9508 - val_squared_difference_loss: 773.9171 - val_KL_divergence_loss: 15.4234 - val_neg_log_likelihood: 448.5274
# Epoch 46/50
#  - 1s - loss: 264.5849 - squared_difference_loss: 374.7989 - KL_divergence_loss: 15.6166 - neg_log_likelihood: 248.9683 - val_loss: 251.5073 - val_squared_difference_loss: 348.6811 - val_KL_divergence_loss: 15.5979 - val_neg_log_likelihood: 235.9094
# Epoch 47/50
#  - 1s - loss: 285.0163 - squared_difference_loss: 415.4250 - KL_divergence_loss: 15.7349 - neg_log_likelihood: 269.2814 - val_loss: 609.5640 - val_squared_difference_loss: 1064.6741 - val_KL_divergence_loss: 15.6580 - val_neg_log_likelihood: 593.9060
# Epoch 48/50
#  - 1s - loss: 266.3193 - squared_difference_loss: 378.1167 - KL_divergence_loss: 15.6920 - neg_log_likelihood: 250.6273 - val_loss: 177.2213 - val_squared_difference_loss: 200.2265 - val_KL_divergence_loss: 15.5391 - val_neg_log_likelihood: 161.6822
# Epoch 49/50
#  - 1s - loss: 282.8630 - squared_difference_loss: 411.4199 - KL_divergence_loss: 15.5841 - neg_log_likelihood: 267.2788 - val_loss: 365.1509 - val_squared_difference_loss: 576.3272 - val_KL_divergence_loss: 15.4184 - val_neg_log_likelihood: 349.7325
# Epoch 50/50
#  - 1s - loss: 268.0901 - squared_difference_loss: 381.8916 - KL_divergence_loss: 15.5754 - neg_log_likelihood: 252.5147 - val_loss: 415.6291 - val_squared_difference_loss: 677.0556 - val_KL_divergence_loss: 15.5324 - val_neg_log_likelihood: 400.0967
# 	Average Validation Squared Error = 78.68076454146126
# Latent Var Num = 3
# Hidden Var Num = 30
# Simulation #3: VAE with 3 Latent Variable(s) and 30 Hidden Variable(s)...
# 	Evaluating model on Fold 1
# Train on 29329 samples, validate on 12570 samples
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-5ce717e8e8ef> in <module>()
#      31                                             X_test,
#      32                                             latent_dimensions=lat_var_num,
# ---> 33                                             intermediate_dimensions=hid_var_num, n_epochs=50)[0]
#      34             if total_nll == float('NaN'):
#      35                 break
#
# <ipython-input-18-e25d8c630645> in evaluate_vae_model(X_train, X_test, latent_dimensions, intermediate_dimensions, n_epochs)
#     112                       batch_size=batch_size,
#     113 #                      callbacks=callbacks_list,
# --> 114                       validation_split=0.3)
#     115
#     116     X_test_encoded = encoder.predict(X_test)  # We take our test data directly from data-space to latent variable
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1710                               initial_epoch=initial_epoch,
#    1711                               steps_per_epoch=steps_per_epoch,
# -> 1712                               validation_steps=validation_steps)
#    1713
#    1714     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
cv_results
# Out:
#             10           20           30          40           50           60
# 3   294.108784   597.136168   296.537311  829.538323   242.739019   290.444039
# 4   306.489237   366.912645   288.961876  345.868654  1562.217812   335.192125
# 5  1360.512203   146.045588   241.453949  982.848449   502.773522  1260.337332
# 6  3059.990420   175.341459   308.329294  518.490705   453.016443  1330.632944
# 7  1011.067096  1078.551828  1096.182228  227.644510   309.594978   151.503265

# %%
import seaborn as sns
sns.heatmap(-cv_results)
plt.xlabel('# Hidden Layer Variables')
plt.ylabel('# Latent Variables')
plt.show()

# %%
X_model_input.shape

# %%
# http://scikit-learn.org/stable/auto_examples/decomposition/plot_pca_vs_fa_model_selection.html#sphx-glr-auto-examples-decomposition-plot-pca-vs-fa-model-selection-py

import numpy as np
import matplotlib.pyplot as plt
from scipy import linalg

from sklearn.decomposition import PCA, FactorAnalysis
from sklearn.covariance import ShrunkCovariance, LedoitWolf
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# #############################################################################
# Fit the models

n_components = np.arange(5, 60, 5)  # options for n_components

def compute_scores(X):
    pca = PCA(svd_solver='full')
    fa = FactorAnalysis()

    pca_scores, fa_scores = [], []
    for n in n_components:
        if n % 1 == 0:
            print ("Running PCA/FA for {} Components...".format(n))
        pca.n_components = n
        fa.n_components = n
        pca_scores.append(np.mean(cross_val_score(pca, X))) # Return the average log-likelihood of all samples.
        fa_scores.append(np.mean(cross_val_score(fa, X))) # Return the average log-likelihood of all samples.
    
    return pca_scores, fa_scores

def shrunk_cov_score(X):
    shrinkages = np.logspace(-2, 0, 30)
    cv = GridSearchCV(ShrunkCovariance(), {'shrinkage': shrinkages})
    return np.mean(cross_val_score(cv.fit(X).best_estimator_, X))

def lw_score(X):
    return np.mean(cross_val_score(LedoitWolf(), X))

print("Computing PCA and FA scores...")
pca_scores, fa_scores = compute_scores(X_model_input)
n_components_pca = n_components[np.argmax(pca_scores)]
n_components_fa = n_components[np.argmax(fa_scores)]

pca = PCA(svd_solver='full', n_components='mle')
pca.fit(X_model_input)
n_components_pca_mle = pca.n_components_

print("best n_components by PCA CV = %d" % n_components_pca)
print("best n_components by FactorAnalysis CV = %d" % n_components_fa)
print("best n_components by PCA MLE = %d" % n_components_pca_mle)

# %%
zip(n_components, pca_scores)

# %%
zip(n_components, fa_scores)

# %%
plt.figure()

#plt.plot(num_latent_vars[:6], -cv_results.loc[num_latent_vars[:6],150], 'g', label='VAE scores')

plt.plot(n_components, pca_scores, 'b', label='Probabilistic PCA scores')
# plt.axvline(n_components_pca, color='b',
#             label='PCA CV: %d' % n_components_pca, linestyle='--')

plt.plot(n_components, fa_scores, 'r', label='Factor Analysis scores')
# plt.axvline(n_components_fa, color='r',
#             label='FactorAnalysis CV: %d' % n_components_fa,
#             linestyle='--')

plt.axhline(lw_score(X), color='orange',
            label='LedoitWolf MLE' % n_components_pca_mle, linestyle='-.')

plt.xlabel('Number of Components')
plt.ylabel('Log-Likelihood')
# plt.ylabel('CV scores')
plt.legend(loc='lower right')

plt.show()
